# %% [markdown]
# ### Plotting in Python using matplotlib.pyplot

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# For compatibility across multiple platforms
import os
IB = os.environ.get('INSTABASE_URI',None) is not None
open = ib.open if IB else open

# %%
# Read Cities.csv and Countries.csv into lists of dictionaries
cities = []
with open('Cities.csv','r') as f:
    rows = csv.DictReader(f)
    for r in rows:
        cities.append(r)
countries = []
with open('Countries.csv','r') as f:
    rows = csv.DictReader(f)
    for r in rows:
        countries.append(r)

# %%
# Introduction to scatterplots
x = [1, 2, 4, 6, 9]
y = [4, 5, 2, 7, 5]
plt.scatter(x, y)
plt.show()

# %%
# Scatterplot of temperature (y) versus latitude (x)
x = []
y = []
for city in cities:
    x.append(city['latitude'])
    y.append(city['temperature'])
plt.xlabel('latitude')
plt.ylabel('temperature')
plt.scatter(x, y)
plt.show()

# %%
# Scatterplot of latitude (y) versus longitude (x) colored by temperature
x = []
y = []
colors = []
for city in cities:
    x.append(city['longitude'])
    y.append(city['latitude'])
    if float(city['temperature']) < 8:
        colors.append('blue')
    elif float(city['temperature']) < 12:
        colors.append('red')
    else: colors.append('green')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.scatter(x, y, c=colors)
plt.show()
x
# Out:
# ['9.92',
#  '-2.08',
#  '18.83',
#  '35.32',
#  '-1.87',
#  '-5.47',
#  '2.30',
#  '4.92',
#  '13.50',
#  '1.52',
#  '-0.53',
#  '32.86',
#  '30.70',
#  '21.32',
#  '23.73',
#  '10.90',
#  '26.92',
#  '-6.97',
#  '23.58',
#  '27.91',
#  '2.18',
#  '16.87',
#  '7.59',
#  '41.14',
#  '-5.96',
#  '20.47',
#  '9.67',
#  '5.32',
#  '13.40',
#  '23.17',
#  '8.53',
#  '30.13',
#  '-2.93',
#  '-1.92',
#  '-3.05',
#  '14.40',
#  '11.34',
#  '7.08',
#  '-0.60',
#  '26.66',
#  '-1.90',
#  '-1.75',
#  '-8.42',
#  '27.97',
#  '17.12',
#  '8.80',
#  '-4.50',
#  '23.70',
#  '16.61',
#  '3.23',
#  '26.10',
#  '19.08',
#  '27.47',
#  '-3.68',
#  '29.07',
#  '18.01',
#  '18.91',
#  '-0.35',
#  '0.12',
#  '-0.98',
#  '15.08',
#  '12.92',
#  '32.07',
#  '31.30',
#  '25.92',
#  '28.86',
#  '28.61',
#  '-8.50',
#  '16.29',
#  '23.83',
#  '26.51',
#  '21.63',
#  '29.08',
#  '5.03',
#  '-6.25',
#  '-3.00',
#  '-3.22',
#  '26.57',
#  '20.08',
#  '19.40',
#  '11.03',
#  '39.49',
#  '41.29',
#  '30.53',
#  '-3.53',
#  '15.56',
#  '8.68',
#  '7.87',
#  '-9.05',
#  '37.38',
#  '6.14',
#  '8.93',
#  '-4.25',
#  '12.00',
#  '-3.59',
#  '15.41',
#  '5.72',
#  '6.58',
#  '17.63',
#  '8.70',
#  '24.93',
#  '38.05',
#  '23.83',
#  '-6.93',
#  '11.45',
#  '11.41',
#  '-4.23',
#  '29.01',
#  '22.11',
#  '33.22',
#  '8.40',
#  '23.88',
#  '35.49',
#  '32.60',
#  '20.66',
#  '30.52',
#  '20.22',
#  '21.12',
#  '21.25',
#  '16.18',
#  '33.43',
#  '33.34',
#  '0.10',
#  '3.08',
#  '1.25',
#  '14.29',
#  '-9.14',
#  '14.51',
#  '24.03',
#  '5.68',
#  '-3.68',
#  '11.62',
#  '37.97',
#  '38.30',
#  '13.03',
#  '27.44',
#  '-4.88',
#  '5.38',
#  '29.27',
#  '15.55',
#  '6.18',
#  '9.21',
#  '27.57',
#  '3.87',
#  '7.35',
#  '-1.13',
#  '7.27',
#  '21.90',
#  '19.85',
#  '10.38',
#  '37.87',
#  '30.42',
#  '10.75',
#  '18.25',
#  '25.47',
#  '-5.83',
#  '13.35',
#  '21.73',
#  '2.90',
#  '12.39',
#  '14.22',
#  '26.09',
#  '24.61',
#  '24.75',
#  '19.27',
#  '16.90',
#  '14.47',
#  '4.03',
#  '24.10',
#  '14.45',
#  '26.25',
#  '12.48',
#  '12.15',
#  '25.97',
#  '-5.67',
#  '13.04',
#  '36.34',
#  '-3.80',
#  '13.38',
#  '24.14',
#  '41.93',
#  '37.03',
#  '21.43',
#  '16.47',
#  '25.62',
#  '5.68',
#  '18.10',
#  '34.78',
#  '-3.95',
#  '20.15',
#  '24.73',
#  '23.75',
#  '34.88',
#  '26.71',
#  '27.51',
#  '1.45',
#  '39.72',
#  '13.80',
#  '21.77',
#  '10.42',
#  '22.25',
#  '17.64',
#  '-0.40',
#  '16.37',
#  '-8.73',
#  '25.32',
#  '21.00',
#  '17.03',
#  '33.36',
#  '-0.89',
#  '28.66',
#  '31.78',
#  '8.56']

# %%
# Introduction to bar charts
bars = ['Bar1', 'Bar2', 'Bar3','Bar4']
heights = [2, 6, 4,8]
plt.xticks([1,2,3,4], bars)
plt.bar([1,2,3,4], heights, align='center')
plt.show()

# %%
# Bar chart showing populations of countries with 'ia' in their name
bars = [] # countries with 'ia' in their name
heights = [] # population of those countries
for country in countries:
    if 'ia' in country['country']:
        bars.append(country['country'])
        heights.append(country['population'])
numbars = len(bars)
# range(numbars) in following command yields [0,1,...,numbars-1]
plt.xticks(range(numbars), bars, rotation='vertical')
plt.bar(range(numbars), heights, align='center')
plt.xlabel('country')
plt.ylabel('population')
plt.show()

# %%
# Introduction to pie charts
sizes = [10, 20, 30]
lbls = ['small', 'medium', 'large']
plt.pie(sizes, labels=lbls, autopct='%1.1f%%')
plt.show()

# %%
# Pie chart showing number of EU countries versus non-EU countries
numEU = 0
numNotEU = 0
for country in countries:
    if country['EU'] == 'yes':
        numEU += 1
    else:
        numNotEU +=1
sizes = [numEU, numNotEU]
lbls = ['EU', 'not EU']
plt.pie(sizes, labels=lbls, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### <font color="green">Exercise: World Cup Data</font>

# %% [markdown]
# #### Read ```Players.csv``` and ```Teams.csv``` into lists of dictionaries

# %%
# Read Players.csv and Teams.csv into lists of dictionaries
players = []
with open('Players.csv','r') as f:
    rows = csv.DictReader(f)
    for r in rows:
        players.append(r)
teams = []
with open('Teams.csv','r') as f:
    rows = csv.DictReader(f)
    for r in rows:
        teams.append(r)

# %% [markdown]
# ### Create a scatterplot of players showing ```passes made (y-axis) versus minutes played (x-axis)```.
# <b>Color each player based on their position (goalkeeper, defender, midfielder, forward)</b>.
# <br>Hint: remember copy-paste-modify approach to programming!

# %%
# your code here
df=pd.read_csv("Players.csv")
df=df[["position","passes","minutes"]]
colors=["yellow","red","blue","green"]
positions=df["position"].unique().tolist()
for i in range(len(colors)):
    x=df[df["position"]==positions[i]]["minutes"].tolist()
    y=df[df["position"]==positions[i]]["passes"].tolist()
    plt.scatter(x,y,label=positions[i],c=colors[i])
plt.legend()
plt.show()

# %% [markdown]
# ### Create a bar chart showing the number of teams with 0, 1, and 2 red cards.
# Reminder: redCards is a string, so convert or compare accordingly

# %%
bars = ['zero', 'one', 'two'] # number of red cards
heights = [0, 0, 0] # number of teams with zero/one/two red cards
# your code here
df=pd.read_csv("Teams.csv")
df=df[["team","redCards"]]
card0=len(df[df["redCards"]==0]["redCards"].tolist())
card1=len(df[df["redCards"]==1]["redCards"].tolist())
card2=len(df[df["redCards"]==2]["redCards"].tolist())
sizes = [card0,card1,card2]
lbls = ["zero","one","two"]
plt.xticks([1,2,3], lbls)
plt.bar([1,2,3], sizes, align='center')
plt.show()

# %% [markdown]
# ### Create a pie chart showing the ```relative percentage of teams with 0, 1, and 2 red cards```.
# Reminder: redCards is a string, so convert or compare accordingly

# %%
#your code here
df=pd.read_csv("Teams.csv")
df=df[["team","redCards"]]
card0=len(df[df["redCards"]==0]["redCards"].tolist())
card1=len(df[df["redCards"]==1]["redCards"].tolist())
card2=len(df[df["redCards"]==2]["redCards"].tolist())
sizes = [card0,card1,card2]
lbls = ["zero","one","two"]
plt.pie(sizes, labels=lbls, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Create a simple <b>LOOP</b> program that asks for a team name then plots a pie chart of the percentages of the positions per team(midfielder,defender,goalkeeper,forward), the loop must break when the user enters <i>quit</i>, If the inputted country is not available, the program must output the string ```Team Not Available in the World Cup.```
#
# A sample prompt is given at the code output below.

# %%
teamName=""
df=pd.read_csv("Players.csv")
positions=df["position"].unique().tolist()
while(teamName!="quit"):
    teamName=input("Enter Team Name:")
    possizes=[]
    if(len(df[df["team"]==teamName])>0):
        for x in range(len(positions)):
            possizes.append(len(df[(df["team"]==teamName)&(df["position"]==positions[x])]))
        plt.pie(possizes, labels=positions, autopct='%1.1f%%')
        plt.show()
    else:
        print("Team not available in world cup")
# Out:
# Enter Team Name:Argentina
# Enter Team Name:Brazil
# Enter Team Name:Philippines
# Team not available in world cup
