# %% [markdown]
# __Name/Section__

# %% [markdown]
# A: Renz Iver Baliber - G01

# %% [markdown]
# # Linear Regression Exercise
#
# This exercise will guide you in implementing the Linear Regression Model to gain intuitions and develop a deeper understanding of the model. These concepts will form as the foundation for more complex models later on.
#
# **You will learn to:**
# - Build the general architecture of a Linear Regression Model.
#     - Implement the Analytical solution for the parameters that minimizes the loss function
#     - Implement the Approximate / Iterative solution for finding the parameters that minimizes the Loss function
#         - Initializing Parameters
#         - Calculating the Cost/Loss/Objective Function
#         - Computing for the gradients of the Loss function with respect to the parameters
#         - Implement gradient descent to update the paramters
#     - Implement linear regression using sci-kit learn

# %% [markdown]
# ## Instructions
# * Read each cell and implement the TODOs sequentially. The markdown/text cells also contain instructions which you need to follow to get the whole notebook working.
# * Do not change the variable names unless the instructor allows you to.
# * Answer all the markdown/text cells with "A: " on them. The answer must strictly consume one line only.
# * You are expected to search how to some functions work on the Internet or via the docs.
# * You may add new cells for "scrap work".
# * The notebooks will undergo a "Restart and Run All" command, so make sure that your code is working properly.
# * You are expected to understand the data set loading and processing separately from this class.
# * You may not reproduce this notebook or share them to anyone.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import csv
import math

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Fix the seed of the random number 
# generator so that your results will match ours
np.random.seed(10)

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Step 1 : Data processing

# %% [markdown]
# **Dataset:**
# We will use the sales prices of houses in Kansas City as our dataset. We will only get one feature / dimension / variable (living area) to be able to visualize the dataset in a 2D plane.

# %% [markdown]
# Here, we will just load the data into the notebook. This data has already been processed, which means that the data is already ready to go for training.
#
# But in reality, you will need to perform some pre-processing and feature extractions after collecting data. For starters, you have to make sure that there are no erroneous answers (eg instead of a number under the column living area, "big" was entered) or empty fields. You may also want to sum/average/std dev some data.
#
# Again, our data here is already clean so we don't have to worry about that :)

# %%
with open('house.csv', 'r') as csvfile:
    rawData = csv.reader(csvfile)
    next(csvfile)
    X = np.empty((0,1), int)
    y = np.empty((0,1), int)
    for row in rawData:
        X = np.vstack([X, np.array([int(row[3])])]) # column for living area
        y = np.append(y, np.array([int(row[7])])) # column for price
        
y = np.expand_dims(y,1) # This is so that the vector of length N will be transformed into a matrix with shape (N,1)

print('Training data shape:',X.shape)
print('Ground truth values shape:',y.shape)
# Out:
# Training data shape: (128, 1)
# Ground truth values shape: (128, 1)

# %% [markdown]
# ## Question:

# %% [markdown]
# __How many data points/entry do we have?__

# %% [markdown]
# A: There a total of 128 data points in the dataset.

# %%
### plot the dataset
plt.xkcd(length=300)

# TODO : Make a scatter plot using plt.scatter. 
#        Place in an x and y label for living area and price
### START CODE HERE ###
plt.scatter(X, y, c="g")
plt.xlabel("living area")
plt.ylabel("price")
plt.show()
### END CODE HERE ###

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Analytical solution/Closed form/Normal Equation
#
# We can quickly compute for the weights by getting the derivative of our objective function and equating it to 0. However, there are some drawbacks to using this method, as you would see in the following cells.
#
# The next cells show the step-by-step process of implementing the closed form solution of linear regression:
# 1. Adding the bias as $x_0$ in the weight vector W
# 1. Finding for the optimal values of weight vector W by using the closed form solution.
# 3. Do some predictions! Now that we have the weights, the label can be solved by plugging in the features x into the linear model.

# %% [markdown]
# ### Step 1: Pre-processing! Add in a vector of one to X to account for the bias

# %% [markdown]
# This just appends a vector of ones to the dimension of your feature vector to accomodate for the bias / constant term in our hypothesis function.

# %%
def feature_transform(X):
    """
    Appends a vector of ones for the bias term.

    Inputs:
    - X: A numpy array of shape (N, D) consisting
         of N samples each of dimension D.

    Returns:
    - f_transform: A numpy array of shape (N, D + 1)
    """
    shape = X.shape

    #############################################################################
    # TODO: Append a vector of ones across the dimension of your input data.    #
    # This accounts for the bias or the constant in your hypothesis function.   #
    #############################################################################
    f_transform = np.concatenate((X,np.ones(shape)),axis=1)
    #############################################################################
    #                              END OF YOUR CODE                             #
    #############################################################################

    return f_transform

transformed_X = feature_transform(X)
print(transformed_X.shape)
# transformed_X
# Out:
# (128, 2)

# %% [markdown]
# __Sanity check:__
#
# Your result should have a shape of (128,2)

# %% [markdown]
# ### Step 2: Train! Compute for the weights via closed form/analytical solution

# %% [markdown]
# Implement the analytic_solution solution without regularization.

# %%
def analytic_solution(X, y):
    """
    Inputs:
    - X: A numpy array of shape (N, D) containing training data; there are N
      training samples each of dimension D.
    - y: A numpy array of shape (N, 1) containing the ground truth values.
    
    Use np.linalg.pinv(for the inverse)w
    
    Outputs:
    - W: weight vector; has shape (D, 1) for dimension D
    """
    
    # This answer unintentionally given away 
    #############################################################################
    # TODO: Calculate for the weights using the closed form. Search up np's pinv#
    #############################################################################
    xT = np.transpose(X)
    to_inverse = np.matmul(xT,X)
    inversed = np.linalg.pinv(to_inverse)
    W = np.matmul((np.matmul(inversed, xT)),y)
    #############################################################################
    #                              END OF YOUR CODE                             #
    #############################################################################
    
    return W

W = analytic_solution(transformed_X,y)
W
# Out:
# array([[    70.22631824],
#        [-10091.12990913]])

# %% [markdown]
# What does this array tell us? Why are there are 2 weights if we only have 1 feature dimension, and 128 training data? Where did 2 come from?

# %% [markdown]
# __Sanity check :__
#
# The resulting weight vector should be approximately equal to:
#
# Weights = [[    70.22631824]
#  [-10091.12990913]]

# %% [markdown]
# ### Step 3: Test! Predict test data with the weights computed

# %%
def predict(X, W):
    """
    Predict values for test data using linear regression.

    Inputs:
    - X: A numpy array of shape (num_test, D) containing test data consisting
         of num_test samples each of dimension D.

    Returns:
    - y: A numpy array of shape (num_test, 1) containing predicted values for the
      test data, where y[i] is the predicted value for the test point X[i].  
    """
    #############################################################################
    # TODO: Since you transformed your training data to include the bias        #
    #       /y-intercept, also transform the features for the test to match     #
    #############################################################################
  

    X_t = feature_transform(X)
    
    #############################################################################
    #                              END OF YOUR CODE                             #
    #############################################################################
    
    #############################################################################
    # TODO: Compute for the predictions of the model on new data using the      #
    # learned weight vectors.                                                   #
    #############################################################################
    prediction = np.matmul(X_t, W) 
    #############################################################################
    #                              END OF YOUR CODE                             #
    #############################################################################

    return prediction

# %% [markdown]
# What will happen if we did not transform the features to add in the y-intercept?

# %%
# plot fitted regression line 

# To show our hypothesis line, we are going to run some x values
X_range = np.expand_dims(np.arange(1200,2800,1),1)

# to predict, we give the data X_range, and the weight vector W
y_range = predict(X_range, W)

plt.scatter(X,y)
plt.plot(X_range,y_range,"b")
plt.ylabel("Price")
plt.xlabel("Living area")
# Out:
# Text(0.5, 0, 'Living area')

# %% [markdown]
# ## Let's test it with our own input
#
# The following input will allow us to estimate a price given a living area.

# %%
print("Type in Q to quit.\n")
while(True):
    print("Living area:")
    a = input()

    if(a == "Q"):
        break;
    elif(a.isdigit()):
        X_range = np.expand_dims([int(a)],1)
        y_range = predict(X_range, W)
        print("For a living area of", a , "sqm, the estimated price is", np.squeeze(y_range),"\n")
    else:
        print("Please enter a valid number.")
# Out:
# Type in Q to quit.
#
# Living area:
# 2000
# For a living area of 2000 sqm, the estimated price is 130361.50657664612
#
# Living area:
# Q

# %% [markdown]
# What you did in the cell above is to test out if it works well with your own input. But is there a better way of objectively saying if the model is doing well or not?
#
# We call this regression metrics, and we're going to try out one now called **root mean squared error** or **RMSE**.
#
# $$
# \operatorname{RMSE}(\hat{y}) = \sqrt{\operatorname{MSE}(\hat{y})} = \sqrt{\operatorname{M}((\hat{y}-y)^2)}
# $$
#
# $\hat{y}$ stands for predicted labels, while $y$ stands for the ground truth label
#
# Computing it can be summarized in 4 simple steps:
# 1. Have a test data ready with known labels. Ideally, these data have never been used in training, but we're going to suspend that rule first and try it with our dataset.
# 2. Get the prediction for every test data, and **subtract** this estimate with the ground truth, and **square** the difference.
# 3. Get the **average** of all the squared differences (#2) of every test data.
# 4. Get the **square root** of the value from #3.

# %%
# TODO : Get all the predictions of the training data by plugging all the X values to the predict func
### START CODE HERE ###
predictions = predict(X, W)
error = (predictions-y)

rmse = np.sqrt(np.mean((error)**2))
print("RMSE: ",rmse)
### END CODE HERE ###
# Out:
# RMSE:  22299.252237014265

# %% [markdown]
# ## Challenge!
# (Yes, this is required)
#
# Use `np.polyfit` to get a similar result.
#
# Compute for the following:
# - The weights of the features for polynomial degree of 1 for the intercept (Do not change this to any other degree yet)
# - Return the estimated price given a living area of `2000`. Use `np.poly1d` to accomplish the feature transform.
# - Graph the model (using `np.plot`) with the data (using `np.scatter`)

# %%
# TODO: Use polyfit with a degree of 1, get the weights
### START CODE HERE ###
polyfitX = np.squeeze(X) # polyfit requires a 1D vector for x, and our current X has a shape of (128,1); squeezing remove this 'unneccesary axis'
squeeze_Y = np.squeeze(y)
model = np.polyfit(polyfitX, squeeze_Y, 1)
model
### END CODE HERE ###, 1
# Out:
# array([    70.22631824, -10091.12990912])

# %%
# TODO: Given a living area of 2000, use np.poly1d to estimate for the price
#       Use the model you created in the cell before
### START CODE HERE ###
livingarea = 2000
p = np.poly1d(model)
x_poly = p(livingarea)
### END CODE HERE ###

# %%
x_poly
# Out:
# 130361.50657664737

# %%
# TODO: Graph the model with the data in the background
### START CODE HERE ###
x_range = np.arange(np.min(X), np.max(X), 10)
y_range = p(x_range)
plt.scatter(X,y)
plt.plot(x_range,y_range,"b")
### END CODE HERE ###

# %% [markdown]
# Next is to implement the iterative solution to linear regression using gradient descent.
#
# For this, we will use sklearn's implementation.

# %% [markdown]
# ## Iterative solution (using gradient descent)
#
# sklearn already has an implementation for the approximate/iterative solution for finding the parameters/weights that minimizes the loss function. It does the following automatically:
#
# 1. Initialize the parameters/weight vector W
#
# 2. Calculate the cost/loss/objective function for current parameters/weights
#
# 3. Compute for the gradients of the loss function with respect to the parameters/weights
#
# 4. Implement gradient descent to update the paramters/weights

# %%
from sklearn.linear_model import SGDRegressor
# TODO : Initialize an SGDRegression with a starting learning rate of 1e-8, 200 iterations
#        Check out the documentation to know how to set these
# Additional : For now, please set the penalty to None, and learning_rate to 'constant'
# Tip : To see the improvement of your model as it trains, set verbose to 1 :D
### START CODE HERE ###
sgd_model = SGDRegressor(max_iter=200, learning_rate='constant', eta0=1e-8, verbose=1)

### END CODE HERE ###
# TODO : Train it with our data X and labels Y
### START CODE HERE ###
y_ravel = y.ravel()
sgd_model.fit(X,y_ravel)
### END CODE HERE ###
# Out:
# -- Epoch 1
# Norm: 64.67, NNZs: 1, Bias: 0.031318, T: 128, Avg. loss: 1128844259.160121
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 63.10, NNZs: 1, Bias: 0.030411, T: 256, Avg. loss: 250487638.179283
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 64.86, NNZs: 1, Bias: 0.031139, T: 384, Avg. loss: 258018157.175760
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 65.91, NNZs: 1, Bias: 0.031498, T: 512, Avg. loss: 254587613.260479
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 66.88, NNZs: 1, Bias: 0.031835, T: 640, Avg. loss: 254202741.552583
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 66.65, NNZs: 1, Bias: 0.031546, T: 768, Avg. loss: 253931576.092848
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 67.84, NNZs: 1, Bias: 0.031994, T: 896, Avg. loss: 255266293.712572
# Total training time: 0.00 seconds.
# Convergence after 7 epochs took 0.00 seconds
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=1e-08, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='constant', loss='squared_loss', max_iter=200,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=1,
#              warm_start=False)

# %% [markdown]
# **Sanity Check :** The loss curve should be decreasing exponentially.

# %% [markdown]
# ## Question:

# %% [markdown]
# __What do we call the eta0, the number of iterations, the learning rate, etc?__

# %% [markdown]
# A: Hyperparameters

# %%
# Visualize what the line would look like at every (a lot of) possible value of x
X_range = np.expand_dims(np.arange(1200,2800,1),1)

# Have the model predict X_range
y_range = sgd_model.predict(X_range)

# TODO : Using plt.scatter, show the data like before
#        Using plt.plot, show the line in blue 'b'
### START CODE HERE ###
plt.scatter(X,y)
plt.plot(X_range,y_range,"b")

### END CODE HERE ###

plt.ylabel("Price")
plt.xlabel("Living area")
# Out:
# Text(0.5, 0, 'Living area')

# %% [markdown]
# ##### Check out the weights (including intercept) from the model.

# %%
# TODO : Print out the coefficients/weights and the intercept
# Tip : Check the model's attributes
### START CODE HERE ###
print("Coefficients: ", sgd_model.coef_)
print("Intercept", sgd_model.intercept_)

### END CODE HERE ###
# Out:
# Coefficients:  [67.84321115]
# Intercept [0.03199416]

# %%
# plot fitted line 
X_range = np.expand_dims(np.arange(1200,2800,1),1)
y_range = sgd_model.predict(X_range) # somethnig wrong with the output
plt.scatter(X,y)
plt.plot(X_range,y_range,"b")
plt.ylabel("Price")
plt.xlabel("Living area")
# Out:
# Text(0.5, 0, 'Living area')

# %% [markdown]
# Try increasing the learning rate to 1e-6. What happened and why?

# %% [markdown]
# A: When the learning rate increased from 1e-8 to 1e-6, the weights and intercept went from ~67.84, 0.03 to ~-1.02+e9,-8400672 which is a significant changed in the results. because of the larger steps that higher learning rate takes, there is a possibility that it overshoots and did not actually reached the optimal loss.

# %% [markdown]
# ## Cross validation and performance metrics

# %% [markdown]
# Regression has a different set of metrics (not accuracy, precision, and recall) because the values are continuous. We instead use different metrics to check for the performance. See this: http://scikit-learn.org/stable/modules/model_evaluation.html

# %%
from sklearn.model_selection import cross_val_predict
from sklearn import metrics

k = 10
y_squeezed = np.squeeze(y)

# TODO : Do cross validation
### START CODE HERE ###
predictions = cross_val_predict(sgd_model, X, y_squeezed, cv=k)
### END CODE HERE ###

# TODO : Show the mean squared error of the model
### START CODE HERE ###
mse = metrics.mean_squared_error(y_squeezed, predictions)
print("Mean Squared Error:", mse)
### END CODE HERE ###

# TODO : Show the mean absolute error of the model
### START CODE HERE ###
mae = metrics.mean_absolute_error(y_squeezed, predictions)
print("Mean Absolute Error", mae)
### END CODE HERE ###
# Out:
# -- Epoch 1
# Norm: 62.95, NNZs: 1, Bias: 0.031197, T: 115, Avg. loss: 1260626590.805012
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 65.13, NNZs: 1, Bias: 0.032130, T: 230, Avg. loss: 272911052.334009
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 66.52, NNZs: 1, Bias: 0.032665, T: 345, Avg. loss: 269420249.281546
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 64.59, NNZs: 1, Bias: 0.031531, T: 460, Avg. loss: 268085177.444269
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 66.45, NNZs: 1, Bias: 0.032330, T: 575, Avg. loss: 267241654.229382
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 65.49, NNZs: 1, Bias: 0.031692, T: 690, Avg. loss: 266443975.535735
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 67.17, NNZs: 1, Bias: 0.032361, T: 805, Avg. loss: 267920514.343219
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 64.00, NNZs: 1, Bias: 0.030590, T: 920, Avg. loss: 266965157.144155
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 64.71, NNZs: 1, Bias: 0.030788, T: 1035, Avg. loss: 269174134.289969
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 64.79, NNZs: 1, Bias: 0.030728, T: 1150, Avg. loss: 270210111.433495
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 63.87, NNZs: 1, Bias: 0.030146, T: 1265, Avg. loss: 267880566.106534
# Total training time: 0.00 seconds.
# Convergence after 11 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 64.56, NNZs: 1, Bias: 0.032204, T: 115, Avg. loss: 1222856394.034928
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 63.85, NNZs: 1, Bias: 0.031719, T: 230, Avg. loss: 257512654.004719
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 65.95, NNZs: 1, Bias: 0.032665, T: 345, Avg. loss: 261008169.603645
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 65.94, NNZs: 1, Bias: 0.032571, T: 460, Avg. loss: 259301644.204624
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 64.94, NNZs: 1, Bias: 0.031947, T: 575, Avg. loss: 257497031.253114
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 64.92, NNZs: 1, Bias: 0.031809, T: 690, Avg. loss: 261022573.818162
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 66.39, NNZs: 1, Bias: 0.032386, T: 805, Avg. loss: 260241350.127402
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 66.73, NNZs: 1, Bias: 0.032433, T: 920, Avg. loss: 259229467.630993
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 64.53, NNZs: 1, Bias: 0.031216, T: 1035, Avg. loss: 260732756.536501
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 63.83, NNZs: 1, Bias: 0.030748, T: 1150, Avg. loss: 260205871.480311
# Total training time: 0.00 seconds.
# Convergence after 10 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 64.58, NNZs: 1, Bias: 0.031718, T: 115, Avg. loss: 1245586175.580779
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 64.13, NNZs: 1, Bias: 0.031410, T: 230, Avg. loss: 251916361.888236
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 65.91, NNZs: 1, Bias: 0.032229, T: 345, Avg. loss: 256213134.660975
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 64.69, NNZs: 1, Bias: 0.031588, T: 460, Avg. loss: 253329063.531841
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 63.83, NNZs: 1, Bias: 0.031095, T: 575, Avg. loss: 252704798.822179
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 64.48, NNZs: 1, Bias: 0.031339, T: 690, Avg. loss: 250216479.514633
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 64.32, NNZs: 1, Bias: 0.031177, T: 805, Avg. loss: 256246465.086895
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 66.61, NNZs: 1, Bias: 0.032209, T: 920, Avg. loss: 254261016.095114
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 63.71, NNZs: 1, Bias: 0.030664, T: 1035, Avg. loss: 253064603.016684
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 67.03, NNZs: 1, Bias: 0.032251, T: 1150, Avg. loss: 251094500.113996
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 66.36, NNZs: 1, Bias: 0.031856, T: 1265, Avg. loss: 256902120.483509
# Total training time: 0.00 seconds.
# Convergence after 11 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 64.69, NNZs: 1, Bias: 0.031826, T: 115, Avg. loss: 1237430485.008120
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 68.14, NNZs: 1, Bias: 0.033310, T: 230, Avg. loss: 250232330.747013
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 67.78, NNZs: 1, Bias: 0.033003, T: 345, Avg. loss: 256768764.965924
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 67.86, NNZs: 1, Bias: 0.032933, T: 460, Avg. loss: 256351723.555106
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 64.59, NNZs: 1, Bias: 0.031180, T: 575, Avg. loss: 258889193.403052
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 65.40, NNZs: 1, Bias: 0.031429, T: 690, Avg. loss: 258207697.427163
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 65.13, NNZs: 1, Bias: 0.031180, T: 805, Avg. loss: 256554926.102701
# Total training time: 0.00 seconds.
# Convergence after 7 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 64.66, NNZs: 1, Bias: 0.031974, T: 115, Avg. loss: 1224251585.241176
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 66.26, NNZs: 1, Bias: 0.032669, T: 230, Avg. loss: 268338316.847317
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 65.99, NNZs: 1, Bias: 0.032517, T: 345, Avg. loss: 264613859.791715
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 66.26, NNZs: 1, Bias: 0.032598, T: 460, Avg. loss: 268469639.743278
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 66.39, NNZs: 1, Bias: 0.032594, T: 575, Avg. loss: 269327970.909939
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 63.54, NNZs: 1, Bias: 0.031081, T: 690, Avg. loss: 265612286.939252
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 62.92, NNZs: 1, Bias: 0.030679, T: 805, Avg. loss: 266685648.032658
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 64.59, NNZs: 1, Bias: 0.031413, T: 920, Avg. loss: 269647013.501129
# Total training time: 0.00 seconds.
# Convergence after 8 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 64.93, NNZs: 1, Bias: 0.032026, T: 115, Avg. loss: 1233312838.585759
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 65.67, NNZs: 1, Bias: 0.032194, T: 230, Avg. loss: 255901060.214432
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 64.06, NNZs: 1, Bias: 0.031232, T: 345, Avg. loss: 252099394.745996
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 65.43, NNZs: 1, Bias: 0.031673, T: 460, Avg. loss: 249379514.615503
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 65.23, NNZs: 1, Bias: 0.031433, T: 575, Avg. loss: 251167835.465006
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 65.51, NNZs: 1, Bias: 0.031386, T: 690, Avg. loss: 254386685.988149
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 64.46, NNZs: 1, Bias: 0.030653, T: 805, Avg. loss: 255470049.353336
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 64.06, NNZs: 1, Bias: 0.030317, T: 920, Avg. loss: 248140514.094123
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 63.07, NNZs: 1, Bias: 0.029652, T: 1035, Avg. loss: 255500579.247294
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 63.46, NNZs: 1, Bias: 0.029704, T: 1150, Avg. loss: 254117792.199286
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 63.97, NNZs: 1, Bias: 0.029830, T: 1265, Avg. loss: 243486055.924560
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 64.41, NNZs: 1, Bias: 0.029835, T: 1380, Avg. loss: 253761909.914938
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 65.02, NNZs: 1, Bias: 0.029927, T: 1495, Avg. loss: 256250089.020772
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 64.17, NNZs: 1, Bias: 0.029313, T: 1610, Avg. loss: 255165933.132643
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 65.62, NNZs: 1, Bias: 0.029809, T: 1725, Avg. loss: 253774274.633114
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 64.46, NNZs: 1, Bias: 0.029047, T: 1840, Avg. loss: 256811196.478194
# Total training time: 0.00 seconds.
# Convergence after 16 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 64.94, NNZs: 1, Bias: 0.031975, T: 115, Avg. loss: 1122505803.184715
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 65.12, NNZs: 1, Bias: 0.031915, T: 230, Avg. loss: 237592211.113043
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 64.46, NNZs: 1, Bias: 0.031438, T: 345, Avg. loss: 241089592.997485
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 65.11, NNZs: 1, Bias: 0.031631, T: 460, Avg. loss: 239771849.923188
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 63.52, NNZs: 1, Bias: 0.030694, T: 575, Avg. loss: 238645396.135814
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 63.47, NNZs: 1, Bias: 0.030564, T: 690, Avg. loss: 239712845.279880
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 63.11, NNZs: 1, Bias: 0.030238, T: 805, Avg. loss: 236151005.842425
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 64.18, NNZs: 1, Bias: 0.030673, T: 920, Avg. loss: 241322047.138197
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 65.34, NNZs: 1, Bias: 0.031160, T: 1035, Avg. loss: 239637241.745494
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 65.54, NNZs: 1, Bias: 0.031100, T: 1150, Avg. loss: 240505666.336570
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 62.38, NNZs: 1, Bias: 0.029374, T: 1265, Avg. loss: 237024734.933748
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 66.60, NNZs: 1, Bias: 0.031367, T: 1380, Avg. loss: 237659581.450509
# Total training time: 0.00 seconds.
# Convergence after 12 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 65.90, NNZs: 1, Bias: 0.032856, T: 115, Avg. loss: 1128627656.497046
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 66.69, NNZs: 1, Bias: 0.033090, T: 230, Avg. loss: 247276235.776914
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 65.25, NNZs: 1, Bias: 0.032214, T: 345, Avg. loss: 248646069.751092
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 63.42, NNZs: 1, Bias: 0.031143, T: 460, Avg. loss: 247133396.570600
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 63.70, NNZs: 1, Bias: 0.031139, T: 575, Avg. loss: 248342490.048267
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 67.17, NNZs: 1, Bias: 0.032724, T: 690, Avg. loss: 244952785.442342
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 66.34, NNZs: 1, Bias: 0.032092, T: 805, Avg. loss: 244956441.626289
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 64.57, NNZs: 1, Bias: 0.031047, T: 920, Avg. loss: 249093139.683514
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 68.61, NNZs: 1, Bias: 0.032904, T: 1035, Avg. loss: 240403901.859129
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 64.60, NNZs: 1, Bias: 0.030781, T: 1150, Avg. loss: 248963075.551513
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 63.61, NNZs: 1, Bias: 0.030208, T: 1265, Avg. loss: 243738622.903745
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 65.32, NNZs: 1, Bias: 0.030915, T: 1380, Avg. loss: 249923896.708414
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 67.68, NNZs: 1, Bias: 0.031946, T: 1495, Avg. loss: 239263775.320597
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 64.57, NNZs: 1, Bias: 0.030268, T: 1610, Avg. loss: 249550885.054091
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 66.46, NNZs: 1, Bias: 0.031152, T: 1725, Avg. loss: 245664565.245514
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 64.86, NNZs: 1, Bias: 0.030214, T: 1840, Avg. loss: 246024244.774479
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 64.59, NNZs: 1, Bias: 0.029937, T: 1955, Avg. loss: 248336959.528257
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 64.80, NNZs: 1, Bias: 0.029851, T: 2070, Avg. loss: 245852658.366797
# Total training time: 0.00 seconds.
# Convergence after 18 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 64.62, NNZs: 1, Bias: 0.031606, T: 116, Avg. loss: 1317606931.838967
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 65.27, NNZs: 1, Bias: 0.031728, T: 232, Avg. loss: 258303270.124625
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 67.03, NNZs: 1, Bias: 0.032423, T: 348, Avg. loss: 251926902.065698
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 63.34, NNZs: 1, Bias: 0.030366, T: 464, Avg. loss: 254390203.582199
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 66.41, NNZs: 1, Bias: 0.031705, T: 580, Avg. loss: 262506729.152751
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 64.47, NNZs: 1, Bias: 0.030539, T: 696, Avg. loss: 260568711.485544
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 66.77, NNZs: 1, Bias: 0.031462, T: 812, Avg. loss: 261887010.512871
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 66.55, NNZs: 1, Bias: 0.031112, T: 928, Avg. loss: 261568248.733006
# Total training time: 0.00 seconds.
# Convergence after 8 epochs took 0.00 seconds
# -- Epoch 1
# Norm: 66.99, NNZs: 1, Bias: 0.033639, T: 116, Avg. loss: 1199120166.151291
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 64.53, NNZs: 1, Bias: 0.032391, T: 232, Avg. loss: 260118900.372966
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 66.12, NNZs: 1, Bias: 0.033077, T: 348, Avg. loss: 260016439.498171
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 65.04, NNZs: 1, Bias: 0.032508, T: 464, Avg. loss: 259915073.700251
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 66.05, NNZs: 1, Bias: 0.032913, T: 580, Avg. loss: 259057594.713415
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 66.40, NNZs: 1, Bias: 0.032995, T: 696, Avg. loss: 258907034.912425
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 65.66, NNZs: 1, Bias: 0.032591, T: 812, Avg. loss: 261300679.093958
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 62.77, NNZs: 1, Bias: 0.031099, T: 928, Avg. loss: 256213334.674065
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 65.94, NNZs: 1, Bias: 0.032605, T: 1044, Avg. loss: 262331580.673513
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 65.88, NNZs: 1, Bias: 0.032514, T: 1160, Avg. loss: 261032388.541279
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 65.30, NNZs: 1, Bias: 0.032154, T: 1276, Avg. loss: 260247900.358420
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 62.71, NNZs: 1, Bias: 0.030725, T: 1392, Avg. loss: 251464487.636560
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 66.30, NNZs: 1, Bias: 0.032398, T: 1508, Avg. loss: 257061864.306402
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 65.29, NNZs: 1, Bias: 0.031806, T: 1624, Avg. loss: 260344080.080800
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 64.57, NNZs: 1, Bias: 0.031400, T: 1740, Avg. loss: 260167903.899749
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 66.15, NNZs: 1, Bias: 0.032106, T: 1856, Avg. loss: 258731672.238511
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 64.53, NNZs: 1, Bias: 0.031225, T: 1972, Avg. loss: 259910567.462791
# Total training time: 0.00 seconds.
# Convergence after 17 epochs took 0.00 seconds
# Mean Squared Error: 504000957.9772109
# Mean Absolute Error 18238.15465719113

# %% [markdown]
# ## <center>fin</center>
